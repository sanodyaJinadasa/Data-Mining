# %% [markdown]
# <a href="https://colab.research.google.com/github/sanodyaJinadasa/Data-Mining/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
df = pd.read_csv("/content/bbc-news-data.csv", sep='\t')
df.head()
# Out:
#    category filename                              title  \
# 0  business  001.txt  Ad sales boost Time Warner profit
# 1  business  002.txt   Dollar gains on Greenspan speech
# 2  business  003.txt  Yukos unit buyer faces loan claim
# 3  business  004.txt  High fuel prices hit BA's profits
# 4  business  005.txt  Pernod takeover talk lifts Domecq
#
#                                              content
# 0   Quarterly profits at US media giant TimeWarne...
# 1   The dollar has hit its highest level against ...
# 2   The owners of embattled Russian oil giant Yuk...
# 3   British Airways has blamed high fuel prices f...
# 4   Shares in UK drinks and food firm Allied Dome...

# %%
documents = df['content']

# %%
vectorizer = CountVectorizer(stop_words='english')
word_counts = vectorizer.fit_transform(documents)
feature_names = vectorizer.get_feature_names_out()

for i in range(1,5):
  lda = LatentDirichletAllocation(n_components=i, random_state=42)
  lda.fit(word_counts)

  print("Discovered Topics:- ")
  for topic_idx, topic in enumerate(lda.components_):
    top_words_idx = topic.argsort()[:-40:-1]
    top_words = [feature_names[i] for i in top_words_idx]
    print(f"Hidden Topic #{topic_idx + 1}: {','.join(top_words)}")

  print("\n")
# Out:
# Discovered Topics:-
# Hidden Topic #1: said,mr,year,people,new,time,world,government,uk,years,best,just,make,told,like,game,film,music,000,labour,number,bbc,way,added,set,market,company,says,home,good,election,going,party,2004,games,second,work,england,think
#
#
# Discovered Topics:-
# Hidden Topic #1: said,mr,year,government,new,people,company,market,firm,uk,000,growth,2004,economy,sales,years,tax,economic,world,companies,firms,bank,time,chief,told,business,expected,public,group,software,months,make,added,china,european,oil,country,deal,security
# Hidden Topic #2: said,mr,people,year,new,time,best,game,film,world,music,just,like,labour,make,bbc,years,games,told,win,play,number,won,home,way,blair,good,uk,players,going,think,set,england,tv,election,old,party,british,added
#
#
# Discovered Topics:-
# ...
